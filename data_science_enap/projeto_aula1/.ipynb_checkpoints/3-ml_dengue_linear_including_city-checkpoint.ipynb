# %%
# Importação das bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read and Merge Dengue Data
# loading do CSV de features e labels e merge dos dados:
# loading do CSV de features e labels e merge dos dados:
df_features = pd.read_csv("dados/dengue_features_train.csv", na_values=[" ","...","na","NA","nan","Na"])
df_labels = pd.read_csv("dados/dengue_labels_train.csv",na_values=[" ","...","na","NA","nan","Na"])
df_dengue = pd.merge(df_features,df_labels)
df_dengue
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0     0.177617                 12.42             297.572857  ...
# 1     0.155486                 22.82             298.211429  ...
# 2     0.170843                 34.54             298.781429  ...
# 3     0.235886                 15.36             298.987143  ...
# 4     0.247340                  7.52             299.518571  ...
# ...        ...                   ...                    ...  ...
# 1451  0.292514                 55.30             299.334286  ...
# 1452  0.225657                 86.47             298.330000  ...
# 1453  0.233714                 58.94             296.598571  ...
# 1454  0.325486                 59.67             296.345714  ...
# 1455  0.315757                 63.22             298.097143  ...
#
#       reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                                73.365714                         12.42
# 1                                77.368571                         22.82
# 2                                82.052857                         34.54
# 3                                80.337143                         15.36
# 4                                80.460000                          7.52
# ...                                    ...                           ...
# 1451                             88.765714                         55.30
# 1452                             91.600000                         86.47
# 1453                             94.280000                         58.94
# 1454                             94.660000                         59.67
# 1455                             89.082857                         63.22
#
#       reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                                 14.012857           2.628571
# 1                                 15.372857           2.371429
# 2                                 16.848571           2.300000
# 3                                 16.672857           2.428571
# 4                                 17.210000           3.014286
# ...                                     ...                ...
# 1451                              18.485714           9.800000
# 1452                              18.070000           7.471429
# 1453                              17.008571           7.500000
# 1454                              16.815714           7.871429
# 1455                              17.355714          11.014286
#
#       station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0              25.442857                 6.900000                29.4
# 1              26.714286                 6.371429                31.7
# 2              26.714286                 6.485714                32.2
# 3              27.471429                 6.771429                33.3
# 4              28.942857                 9.371429                35.0
# ...                  ...                      ...                 ...
# 1451           28.633333                11.933333                35.4
# 1452           27.433333                10.500000                34.7
# 1453           24.400000                 6.900000                32.2
# 1454           25.433333                 8.733333                31.2
# 1455           27.475000                 9.900000                33.7
#
#       station_min_temp_c  station_precip_mm  total_cases
# 0                   20.0               16.0            4
# 1                   22.2                8.6            5
# 2                   22.8               41.4            4
# 3                   23.3                4.0            3
# 4                   23.9                5.8            6
# ...                  ...                ...          ...
# 1451                22.4               27.0            5
# 1452                21.7               36.6            8
# 1453                19.2                7.4            1
# 1454                21.0               16.0            1
# 1455                22.2               20.4            4
#
# [1456 rows x 25 columns]

# %%
### Contando dados nulos:
df_dengue.isna().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# dtype: int64

# %%
### Suprimindo as colunas que identificam nomes, períodos ou ciclos da tabela de treino e teste.
df_dengue = df_dengue[['city',"year",'weekofyear', 'ndvi_ne', 'ndvi_nw',
       'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
       'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
       'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
       'reanalysis_precip_amt_kg_per_m2',
       'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
       'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
       'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
       'station_min_temp_c', 'station_precip_mm', 'total_cases']]

# %%
#### Converting categorical city to once_hot_encoder and merge again with df
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown="ignore")
cities = pd.DataFrame(enc.fit_transform(df_dengue[["city"]]).toarray(), columns=[["iq", "sj"]])
df_dengue = pd.merge(cities, df_dengue, left_index=True ,right_index=True)
df_dengue.drop(columns="city", inplace=True)

# %%
### Rename colums names
df_dengue.rename(columns= {('iq',):"iq", ('sj',) :"sj"}, inplace=True)

# %%
df_dengue
# Out:
#        iq   sj  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0     0.0  1.0  1990          18  0.122600  0.103725  0.198483  0.177617
# 1     0.0  1.0  1990          19  0.169900  0.142175  0.162357  0.155486
# 2     0.0  1.0  1990          20  0.032250  0.172967  0.157200  0.170843
# 3     0.0  1.0  1990          21  0.128633  0.245067  0.227557  0.235886
# 4     0.0  1.0  1990          22  0.196200  0.262200  0.251200  0.247340
# ...   ...  ...   ...         ...       ...       ...       ...       ...
# 1451  1.0  0.0  2010          21  0.342750  0.318900  0.256343  0.292514
# 1452  1.0  0.0  2010          22  0.160157  0.160371  0.136043  0.225657
# 1453  1.0  0.0  2010          23  0.247057  0.146057  0.250357  0.233714
# 1454  1.0  0.0  2010          24  0.333914  0.245771  0.278886  0.325486
# 1455  1.0  0.0  2010          25  0.298186  0.232971  0.274214  0.315757
#
#       precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0                    12.42             297.572857  ...
# 1                    22.82             298.211429  ...
# 2                    34.54             298.781429  ...
# 3                    15.36             298.987143  ...
# 4                     7.52             299.518571  ...
# ...                    ...                    ...  ...
# 1451                 55.30             299.334286  ...
# 1452                 86.47             298.330000  ...
# 1453                 58.94             296.598571  ...
# 1454                 59.67             296.345714  ...
# 1455                 63.22             298.097143  ...
#
#       reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                                73.365714                         12.42
# 1                                77.368571                         22.82
# 2                                82.052857                         34.54
# 3                                80.337143                         15.36
# 4                                80.460000                          7.52
# ...                                    ...                           ...
# 1451                             88.765714                         55.30
# 1452                             91.600000                         86.47
# 1453                             94.280000                         58.94
# 1454                             94.660000                         59.67
# 1455                             89.082857                         63.22
#
#       reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                                 14.012857           2.628571
# 1                                 15.372857           2.371429
# 2                                 16.848571           2.300000
# 3                                 16.672857           2.428571
# 4                                 17.210000           3.014286
# ...                                     ...                ...
# 1451                              18.485714           9.800000
# 1452                              18.070000           7.471429
# 1453                              17.008571           7.500000
# 1454                              16.815714           7.871429
# 1455                              17.355714          11.014286
#
#       station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0              25.442857                 6.900000                29.4
# 1              26.714286                 6.371429                31.7
# 2              26.714286                 6.485714                32.2
# 3              27.471429                 6.771429                33.3
# 4              28.942857                 9.371429                35.0
# ...                  ...                      ...                 ...
# 1451           28.633333                11.933333                35.4
# 1452           27.433333                10.500000                34.7
# 1453           24.400000                 6.900000                32.2
# 1454           25.433333                 8.733333                31.2
# 1455           27.475000                 9.900000                33.7
#
#       station_min_temp_c  station_precip_mm  total_cases
# 0                   20.0               16.0            4
# 1                   22.2                8.6            5
# 2                   22.8               41.4            4
# 3                   23.3                4.0            3
# 4                   23.9                5.8            6
# ...                  ...                ...          ...
# 1451                22.4               27.0            5
# 1452                21.7               36.6            8
# 1453                19.2                7.4            1
# 1454                21.0               16.0            1
# 1455                22.2               20.4            4
#
# [1456 rows x 25 columns]

# %%
#### Change Nan values by mean (train input)
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy="mean")
df_dengue_clean = imp.fit(df_dengue).transform(df_dengue)
df_dengue_clean = pd.DataFrame(df_dengue_clean)
df_dengue_clean
# Out:
#        0    1       2     3         4         5         6         7      8   \
# 0     0.0  1.0  1990.0  18.0  0.122600  0.103725  0.198483  0.177617  12.42
# 1     0.0  1.0  1990.0  19.0  0.169900  0.142175  0.162357  0.155486  22.82
# 2     0.0  1.0  1990.0  20.0  0.032250  0.172967  0.157200  0.170843  34.54
# 3     0.0  1.0  1990.0  21.0  0.128633  0.245067  0.227557  0.235886  15.36
# 4     0.0  1.0  1990.0  22.0  0.196200  0.262200  0.251200  0.247340   7.52
# ...   ...  ...     ...   ...       ...       ...       ...       ...    ...
# 1451  1.0  0.0  2010.0  21.0  0.342750  0.318900  0.256343  0.292514  55.30
# 1452  1.0  0.0  2010.0  22.0  0.160157  0.160371  0.136043  0.225657  86.47
# 1453  1.0  0.0  2010.0  23.0  0.247057  0.146057  0.250357  0.233714  58.94
# 1454  1.0  0.0  2010.0  24.0  0.333914  0.245771  0.278886  0.325486  59.67
# 1455  1.0  0.0  2010.0  25.0  0.298186  0.232971  0.274214  0.315757  63.22
#
#               9   ...         15     16         17         18         19  \
# 0     297.572857  ...  73.365714  12.42  14.012857   2.628571  25.442857
# 1     298.211429  ...  77.368571  22.82  15.372857   2.371429  26.714286
# 2     298.781429  ...  82.052857  34.54  16.848571   2.300000  26.714286
# 3     298.987143  ...  80.337143  15.36  16.672857   2.428571  27.471429
# 4     299.518571  ...  80.460000   7.52  17.210000   3.014286  28.942857
# ...          ...  ...        ...    ...        ...        ...        ...
# 1451  299.334286  ...  88.765714  55.30  18.485714   9.800000  28.633333
# 1452  298.330000  ...  91.600000  86.47  18.070000   7.471429  27.433333
# 1453  296.598571  ...  94.280000  58.94  17.008571   7.500000  24.400000
# 1454  296.345714  ...  94.660000  59.67  16.815714   7.871429  25.433333
# 1455  298.097143  ...  89.082857  63.22  17.355714  11.014286  27.475000
#
#              20    21    22    23   24
# 0      6.900000  29.4  20.0  16.0  4.0
# 1      6.371429  31.7  22.2   8.6  5.0
# 2      6.485714  32.2  22.8  41.4  4.0
# 3      6.771429  33.3  23.3   4.0  3.0
# 4      9.371429  35.0  23.9   5.8  6.0
# ...         ...   ...   ...   ...  ...
# 1451  11.933333  35.4  22.4  27.0  5.0
# 1452  10.500000  34.7  21.7  36.6  8.0
# 1453   6.900000  32.2  19.2   7.4  1.0
# 1454   8.733333  31.2  21.0  16.0  1.0
# 1455   9.900000  33.7  22.2  20.4  4.0
#
# [1456 rows x 25 columns]

# %%
# %%html
# <h2 align="center"> 1 - Treinando  modelo de ML, com a variável "city", one encoder - Regressão linear </h2>
# Out:
# <h2 align="center"> 1 - Treinando  modelo de ML, com a variável "city", one encoder - Regressão linear </h2>

# %%
# SPLIT dos dados - training and test
from sklearn.model_selection import train_test_split
y = df_dengue_clean[24]
X = df_dengue_clean.drop(columns=24, axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y, X
# Out:
# (0       4.0
#  1       5.0
#  2       4.0
#  3       3.0
#  4       6.0
#         ...
#  1451    5.0
#  1452    8.0
#  1453    1.0
#  1454    1.0
#  1455    4.0
#  Name: 24, Length: 1456, dtype: float64,
#         0    1       2     3         4         5         6         7      8   \
#  0     0.0  1.0  1990.0  18.0  0.122600  0.103725  0.198483  0.177617  12.42
#  1     0.0  1.0  1990.0  19.0  0.169900  0.142175  0.162357  0.155486  22.82
#  2     0.0  1.0  1990.0  20.0  0.032250  0.172967  0.157200  0.170843  34.54
#  3     0.0  1.0  1990.0  21.0  0.128633  0.245067  0.227557  0.235886  15.36
#  4     0.0  1.0  1990.0  22.0  0.196200  0.262200  0.251200  0.247340   7.52
#  ...   ...  ...     ...   ...       ...       ...       ...       ...    ...
#  1451  1.0  0.0  2010.0  21.0  0.342750  0.318900  0.256343  0.292514  55.30
#  1452  1.0  0.0  2010.0  22.0  0.160157  0.160371  0.136043  0.225657  86.47
#  1453  1.0  0.0  2010.0  23.0  0.247057  0.146057  0.250357  0.233714  58.94
#  1454  1.0  0.0  2010.0  24.0  0.333914  0.245771  0.278886  0.325486  59.67
#  1455  1.0  0.0  2010.0  25.0  0.298186  0.232971  0.274214  0.315757  63.22
#
#                9   ...      14         15     16         17         18  \
#  0     297.572857  ...   32.00  73.365714  12.42  14.012857   2.628571
#  1     298.211429  ...   17.94  77.368571  22.82  15.372857   2.371429
#  2     298.781429  ...   26.10  82.052857  34.54  16.848571   2.300000
#  3     298.987143  ...   13.90  80.337143  15.36  16.672857   2.428571
#  4     299.518571  ...   12.20  80.460000   7.52  17.210000   3.014286
#  ...          ...  ...     ...        ...    ...        ...        ...
#  1451  299.334286  ...   45.00  88.765714  55.30  18.485714   9.800000
#  1452  298.330000  ...  207.10  91.600000  86.47  18.070000   7.471429
#  1453  296.598571  ...   50.60  94.280000  58.94  17.008571   7.500000
#  1454  296.345714  ...   62.33  94.660000  59.67  16.815714   7.871429
#  1455  298.097143  ...   36.90  89.082857  63.22  17.355714  11.014286
#
#               19         20    21    22    23
#  0     25.442857   6.900000  29.4  20.0  16.0
#  1     26.714286   6.371429  31.7  22.2   8.6
#  2     26.714286   6.485714  32.2  22.8  41.4
#  3     27.471429   6.771429  33.3  23.3   4.0
#  4     28.942857   9.371429  35.0  23.9   5.8
#  ...         ...        ...   ...   ...   ...
#  1451  28.633333  11.933333  35.4  22.4  27.0
#  1452  27.433333  10.500000  34.7  21.7  36.6
#  1453  24.400000   6.900000  32.2  19.2   7.4
#  1454  25.433333   8.733333  31.2  21.0  16.0
#  1455  27.475000   9.900000  33.7  22.2  20.4
#
#  [1456 rows x 24 columns])

# %%
## Training a model
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_test,y_test)
#### Modelo com baixíssima qualidade de Score para regressão Linear
# Out:
# 0.17525441632504257

# %%
# %%html
# <h2 align center> Score R2 do primeiro modelo de ML = 0.175
# Out:
# <h2 align center> Score R2 do primeiro modelo de ML = 0.175

# %%
# %%html
# <h2 align="center"> 2 - No segundo modelo - vamos normalizar os valores de X, antes do split. </h2>
# Out:
# <h2 align="center"> 2 - No segundo modelo - vamos normalizar os valores de X, antes do split. </h2>

# %%
# Normalize X values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(X)
X_norm = scaler.transform(X)
X_norm
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.17419355, 0.48623853,
#         0.02944966],
#        [0.        , 1.        , 0.        , ..., 0.32258065, 0.68807339,
#         0.01582919],
#        [0.        , 1.        , 0.        , ..., 0.35483871, 0.74311927,
#         0.07620099],
#        ...,
#        [1.        , 0.        , 1.        , ..., 0.35483871, 0.41284404,
#         0.01362047],
#        [1.        , 0.        , 1.        , ..., 0.29032258, 0.57798165,
#         0.02944966],
#        [1.        , 0.        , 1.        , ..., 0.4516129 , 0.68807339,
#         0.03754832]])

# %%
# split data
X_train_norm, X_test_norm, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=600)

# %%
# Train a normalized model
lm = LinearRegression()
lm.fit(X_train_norm,y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_test_norm, y_test)
# Out:
# 0.1802916169330011

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, lm.predict(X_test_norm))
# Out:
# 20.126907258917058

# %%
# %%html
# <h3> Até o momento, houve desconsiderável evolução do modelo linear, devido à baixa linearidade
# de correlação entre features e labels </h3>
# <h2 align = center> 3 - Implementar a técnica de transformada log do label </h2>
# Out:
# <h3> Até o momento, houve desconsiderável evolução do modelo linear, devido à baixa linearidade
# de correlação entre features e labels </h3>
# <h2 align = center> 3 - Implementar a técnica de transformada log do label </h2>

# %%
# Transformada em Log do Array
y_arr = np.array(y)
y_log = []
for x in y_arr:
    if x==0:
        y_log.append(x)
    else:
        y_log.append(np.log(x))

# %%
### Split dos dados
X_train_norm, X_test_norm, y_log_train, y_log_test = train_test_split(X_norm, y_log, test_size=0.3, random_state=42)

# %%
# Train a normalized model and log label
lm = LinearRegression()
lm.fit(X_train,y_log_train)
# Out:
# LinearRegression()

# %%
round(lm.score(X_test, y_log_test),2)
# Out:
# 0.4

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(lm, X_train, y_log_train, cv=5, scoring="r2").mean()
# Out:
# 0.358224729578339

# %%
# %%html
# <h3> Nice ! O modelo progrediu para R2 = 0.4, com a transformação log do label (feature Engineer).
# Out:
# <h3> Nice ! O modelo progrediu para R2 = 0.4, com a transformação log do label (feature Engineer).

# %%
#### Y_test vs Predict - plot
plt.figure(figsize=(10,6))
plt.scatter(lm.predict(X_test_norm), y_log_test)
plt.title("Scatter, Predict vs original test, with LOG transform to a better regression prediction")
plt.show()

# %%
# %%html
# <br><br>
# <h2> ANALISAR OS COEFICIENTES DE LINEARIDADE E FAZER O TESTE COM OS MAIS SIGNIFICATIVOS</h2>
# <br><br>
# Out:
# <br><br>
# <h2> ANALISAR OS COEFICIENTES DE LINEARIDADE E FAZER O TESTE COM OS MAIS SIGNIFICATIVOS</h2>
# <br><br>

# %%
columns = pd.DataFrame(df_dengue.columns)

# %%
### Listando a significancia dos coeficientes para o modelo.
coef = lm.coef_
pd.DataFrame(coef, X.columns)
linear_coef_dict = {"column" : X.columns, "coef" : coef}
linear_coef_log_model = pd.DataFrame(linear_coef_dict).abs().sort_values(by="coef", ascending=False)
pd.merge(linear_coef_log_model, columns, left_index=True, right_index=True)
# Out:
#     column      coef                                      0
# 17    17.0  2.248113  reanalysis_specific_humidity_g_per_kg
# 11    11.0  1.804889            reanalysis_dew_point_temp_k
# 6      6.0  0.848518                                ndvi_se
# 7      7.0  0.611106                                ndvi_sw
# 0      0.0  0.244524                                     iq
# 1      1.0  0.244524                                     sj
# 19    19.0  0.204515                     station_avg_temp_c
# 9      9.0  0.176241                  reanalysis_air_temp_k
# 4      4.0  0.174318                                ndvi_ne
# 10    10.0  0.119975                  reanalysis_avg_temp_k
# 5      5.0  0.095855                                ndvi_nw
# 12    12.0  0.073025              reanalysis_max_air_temp_k
# 18    18.0  0.066272                      reanalysis_tdtr_k
# 21    21.0  0.059673                     station_max_temp_c
# 15    15.0  0.056825   reanalysis_relative_humidity_percent
# 2      2.0  0.054732                                   year
# 20    20.0  0.009767                station_diur_temp_rng_c
# 13    13.0  0.009198              reanalysis_min_air_temp_k
# 3      3.0  0.005288                             weekofyear
# 23    23.0  0.001444                      station_precip_mm
# 22    22.0  0.001209                     station_min_temp_c
# 16    16.0  0.001172           reanalysis_sat_precip_amt_mm
# 8      8.0  0.001172                   precipitation_amt_mm
# 14    14.0  0.000400        reanalysis_precip_amt_kg_per_m2

# %%
X_new = pd.DataFrame(X_norm)[[17,11,6,7,0,1,19,9,4,10,5,12]]
X_train_norm, X_test_norm, y_log_train, y_log_test = train_test_split(X_new, y_log, test_size=0.3, random_state=42)
lm = LinearRegression()
lm.fit(X_train_norm,y_log_train)
round(lm.score(X_test_norm, y_log_test),2)
# Out:
# 0.38

# %%
plt.scatter(y_log_test, lm.predict(X_test_norm))

# %%
# %%html
# <h2 align="center"> 5 - Transformações e pipeline Polinomial </h2>
# Out:
# <h2 align="center"> 5 - Transformações e pipeline Polinomial </h2>

# %%
## Testando um modelo de pipeline com X new
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline

# %%
df_dengue_clean
# Out:
#        0    1       2     3         4         5         6         7      8   \
# 0     0.0  1.0  1990.0  18.0  0.122600  0.103725  0.198483  0.177617  12.42
# 1     0.0  1.0  1990.0  19.0  0.169900  0.142175  0.162357  0.155486  22.82
# 2     0.0  1.0  1990.0  20.0  0.032250  0.172967  0.157200  0.170843  34.54
# 3     0.0  1.0  1990.0  21.0  0.128633  0.245067  0.227557  0.235886  15.36
# 4     0.0  1.0  1990.0  22.0  0.196200  0.262200  0.251200  0.247340   7.52
# ...   ...  ...     ...   ...       ...       ...       ...       ...    ...
# 1451  1.0  0.0  2010.0  21.0  0.342750  0.318900  0.256343  0.292514  55.30
# 1452  1.0  0.0  2010.0  22.0  0.160157  0.160371  0.136043  0.225657  86.47
# 1453  1.0  0.0  2010.0  23.0  0.247057  0.146057  0.250357  0.233714  58.94
# 1454  1.0  0.0  2010.0  24.0  0.333914  0.245771  0.278886  0.325486  59.67
# 1455  1.0  0.0  2010.0  25.0  0.298186  0.232971  0.274214  0.315757  63.22
#
#               9   ...         15     16         17         18         19  \
# 0     297.572857  ...  73.365714  12.42  14.012857   2.628571  25.442857
# 1     298.211429  ...  77.368571  22.82  15.372857   2.371429  26.714286
# 2     298.781429  ...  82.052857  34.54  16.848571   2.300000  26.714286
# 3     298.987143  ...  80.337143  15.36  16.672857   2.428571  27.471429
# 4     299.518571  ...  80.460000   7.52  17.210000   3.014286  28.942857
# ...          ...  ...        ...    ...        ...        ...        ...
# 1451  299.334286  ...  88.765714  55.30  18.485714   9.800000  28.633333
# 1452  298.330000  ...  91.600000  86.47  18.070000   7.471429  27.433333
# 1453  296.598571  ...  94.280000  58.94  17.008571   7.500000  24.400000
# 1454  296.345714  ...  94.660000  59.67  16.815714   7.871429  25.433333
# 1455  298.097143  ...  89.082857  63.22  17.355714  11.014286  27.475000
#
#              20    21    22    23   24
# 0      6.900000  29.4  20.0  16.0  4.0
# 1      6.371429  31.7  22.2   8.6  5.0
# 2      6.485714  32.2  22.8  41.4  4.0
# 3      6.771429  33.3  23.3   4.0  3.0
# 4      9.371429  35.0  23.9   5.8  6.0
# ...         ...   ...   ...   ...  ...
# 1451  11.933333  35.4  22.4  27.0  5.0
# 1452  10.500000  34.7  21.7  36.6  8.0
# 1453   6.900000  32.2  19.2   7.4  1.0
# 1454   8.733333  31.2  21.0  16.0  1.0
# 1455   9.900000  33.7  22.2  20.4  4.0
#
# [1456 rows x 25 columns]

# %%
# %%html
# <h2> Testes com Min Max de todos os dados
# Out:
# <h2> Testes com Min Max de todos os dados

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_min_max = MinMaxScaler(feature_range=(0,1))
df_dengue_scaled = scaler.fit_transform(df_dengue_clean)
df_dengue_scaled = pd.DataFrame(df_dengue_scaled)

# %%
y = df_dengue_scaled[24]
X = df_dengue_scaled.drop(columns=24, axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
lm_scaled = LinearRegression()
lm_scaled.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm_scaled.score(X_test, y_test)
# Out:
# 0.18829205188573928

# %%
### Aplicando a transformação polinomial somente à X

# %%
y = df_dengue_clean[24]
X = df_dengue_clean.drop(columns=24, axis=1)

# %%
#### Aplicando Poly somente à X
poly = PolynomialFeatures(2)
X_poly = pd.DataFrame(poly.fit_transform(X))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=600)

# %%
lm_poly = LinearRegression()
lm_poly.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm_poly.score(X_test, y_test)
# Out:
# 0.07577754711434226

# %%
# %%html
# <h3> Convertendo y para um valor logaritmo e min max em todo o dataset
# Out:
# <h3> Convertendo y para um valor logaritmo e min max em todo o dataset

# %%
y = df_dengue_clean[24]
X = df_dengue_clean.drop(columns=24, axis=1)

# %%
# Transformada em Log do Array
y_arr = np.array(y)
y_log = []
for x in y_arr:
    if x==0:
        y_log.append(x)
    else:
        y_log.append(np.log(x))

# %%
df_dengue_log = pd.merge(X, pd.DataFrame(y_log), right_index=True, left_index=True)

# %%
df_dengue_log
# Out:
#       0_x    1       2     3         4         5         6         7      8  \
# 0     0.0  1.0  1990.0  18.0  0.122600  0.103725  0.198483  0.177617  12.42
# 1     0.0  1.0  1990.0  19.0  0.169900  0.142175  0.162357  0.155486  22.82
# 2     0.0  1.0  1990.0  20.0  0.032250  0.172967  0.157200  0.170843  34.54
# 3     0.0  1.0  1990.0  21.0  0.128633  0.245067  0.227557  0.235886  15.36
# 4     0.0  1.0  1990.0  22.0  0.196200  0.262200  0.251200  0.247340   7.52
# ...   ...  ...     ...   ...       ...       ...       ...       ...    ...
# 1451  1.0  0.0  2010.0  21.0  0.342750  0.318900  0.256343  0.292514  55.30
# 1452  1.0  0.0  2010.0  22.0  0.160157  0.160371  0.136043  0.225657  86.47
# 1453  1.0  0.0  2010.0  23.0  0.247057  0.146057  0.250357  0.233714  58.94
# 1454  1.0  0.0  2010.0  24.0  0.333914  0.245771  0.278886  0.325486  59.67
# 1455  1.0  0.0  2010.0  25.0  0.298186  0.232971  0.274214  0.315757  63.22
#
#                9  ...         15     16         17         18         19  \
# 0     297.572857  ...  73.365714  12.42  14.012857   2.628571  25.442857
# 1     298.211429  ...  77.368571  22.82  15.372857   2.371429  26.714286
# 2     298.781429  ...  82.052857  34.54  16.848571   2.300000  26.714286
# 3     298.987143  ...  80.337143  15.36  16.672857   2.428571  27.471429
# 4     299.518571  ...  80.460000   7.52  17.210000   3.014286  28.942857
# ...          ...  ...        ...    ...        ...        ...        ...
# 1451  299.334286  ...  88.765714  55.30  18.485714   9.800000  28.633333
# 1452  298.330000  ...  91.600000  86.47  18.070000   7.471429  27.433333
# 1453  296.598571  ...  94.280000  58.94  17.008571   7.500000  24.400000
# 1454  296.345714  ...  94.660000  59.67  16.815714   7.871429  25.433333
# 1455  298.097143  ...  89.082857  63.22  17.355714  11.014286  27.475000
#
#              20    21    22    23       0_y
# 0      6.900000  29.4  20.0  16.0  1.386294
# 1      6.371429  31.7  22.2   8.6  1.609438
# 2      6.485714  32.2  22.8  41.4  1.386294
# 3      6.771429  33.3  23.3   4.0  1.098612
# 4      9.371429  35.0  23.9   5.8  1.791759
# ...         ...   ...   ...   ...       ...
# 1451  11.933333  35.4  22.4  27.0  1.609438
# 1452  10.500000  34.7  21.7  36.6  2.079442
# 1453   6.900000  32.2  19.2   7.4  0.000000
# 1454   8.733333  31.2  21.0  16.0  0.000000
# 1455   9.900000  33.7  22.2  20.4  1.386294
#
# [1456 rows x 25 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_min_max = MinMaxScaler(feature_range=(0,1))
df_dengue_scaled_log = scaler.fit_transform(df_dengue_log)
df_dengue_scaled_log = pd.DataFrame(df_dengue_scaled_log)

# %%
y = df_dengue_scaled_log[24]
X = df_dengue_scaled_log.drop(columns=24, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=600)

# %%
lm_scaled_log = LinearRegression()
lm_scaled_log.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm_scaled_log.score(X_test, y_test)
# Out:
# 0.3992977821976945
